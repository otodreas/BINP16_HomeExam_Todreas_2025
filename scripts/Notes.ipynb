# %% [markdown]
# ### Question 2

# %%
# Define function
def gc_content(sequence, window_size):
    gc_content_percentages = []
    for i in range(len(sequence) - window_size + 1):
        frame = sequence[i : i + window_size].upper()
        gc_count = frame.count("G") + frame.count("C")
        gc_percent = round(gc_count / window_size * 100, 1)
        gc_content_percentages.append(gc_percent)
    return gc_content_percentages

# Test
s = "AAGGTTCC"
w = 3
print(f"inputs: {s}, {w}")
print(f"outputs: {gc_content(s, w)}")
# Out:
# inputs: AAGGTTCC, 3
# outputs: [33.3, 66.7, 66.7, 33.3, 33.3, 66.7]

# %%
import os
n_output_files = [f for f in os.listdir() if f.startswith('a')]
print(n_output_files)
os.listdir()
# Out:
# ['answers', 'a.txt']
# ['answers',
#  'a.txt',
#  'examples',
#  'manage_examples.py',
#  '.ipynb_checkpoints',
#  'Notes.ipynb']

# %%
x = {1: 'a', 2: 'b'}
x.values()
for i in x:
    print(i)
    print(x.get(i))
# Out:
# 1
# a
# 2
# b

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
x = [1, 3, 5, 9, 24]
fig, ax = plt.subplots()
ax.hist(x)
ax.set_yticks([tick for tick in ax.get_yticks() if tick % 1 == 0])
ax.set_ylabel("y")
ax.set_xlabel("x")
fig.suptitle("title")
fig.tight_layout()
fig.savefig("test.png")

# %%
import os
# for f in os.listdir() if f.endswith(".ipynb"):
for f in [f for f in os.listdir() if f.endswith(".ipynb")]:
    print(f)
# Out:
# Notes.ipynb

# %%
print(type(None) == None)
# Out:
# False

# %%
"aaddss".count("d", "s")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 "aaddss".count("d", "s")
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
try:
    
except ZeroDivisionError:
    f("Window size cannot be 0")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
({'a', 's'} | set("aaaaasd"))
# Out:
# {'a', 'd', 's'}
